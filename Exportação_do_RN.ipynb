# %% [markdown]
# # Análise exploratória dos dados de exportação do RN
#
# ## Fonte dos dados
# > ![](https://lh4.googleusercontent.com/proxy/fXgKw9x3Ea2Yv-B5CtmnQnFjuRco5o10y3lZahcsz3jBaEmnVUyPKj1EcigqdJAjHz0ZVnITm2Bll7No15Ylxp3ng2EW08BKudKAkJoG)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Baixa planilhas
# !wget --header="Authorization: token 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" "https://raw.githubusercontent.com/jgoulartf/analise_exportacoes_rn/main/V_EXPORTACAO_GERAL_1997-01_2024-12_CONTINENTE_EXCEL.xlsx" -O planilha_exportacoes_rn_continente.xlsx
# !wget --header="Authorization: token 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" "https://raw.githubusercontent.com/jgoulartf/analise_exportacoes_rn/main/V_EXPORTACAO_GERAL_1997-01_2024-12_BLOCOS_ECONOMICOS_EXCEL.xlsx" -O planilha_exportacoes_rn_blocos_economicos.xlsx
# Out:
# --2024-10-18 17:48:05--  https://raw.githubusercontent.com/jgoulartf/analise_exportacoes_rn/main/V_EXPORTACAO_GERAL_1997-01_2024-12_CONTINENTE_EXCEL.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8753660 (8.3M) [application/octet-stream]
# Saving to: ‘planilha_exportacoes_rn_continente.xlsx’
#
# planilha_exportacoe 100%[===================>]   8.35M  --.-KB/s    in 0.04s
#
# 2024-10-18 17:48:05 (225 MB/s) - ‘planilha_exportacoes_rn_continente.xlsx’ saved [8753660/8753660]
#
# --2024-10-18 17:48:05--  https://raw.githubusercontent.com/jgoulartf/analise_exportacoes_rn/main/V_EXPORTACAO_GERAL_1997-01_2024-12_BLOCOS_ECONOMICOS_EXCEL.xlsx
# ...

# %%
import pandas as pd

# Carrega excel em um dataframe
dataset_exportacoes_rn_continente = pd.read_excel('/content/planilha_exportacoes_rn_continente.xlsx')
dataset_exportacoes_rn_blocos_economicos = pd.read_excel('/content/planilha_exportacoes_rn_continente.xlsx')
# Exiba as primeiras linhas do DataFrame
dataset_exportacoes_rn
# Out:
#         Ano           Mês        UF do Produto  \
# 0      2024  09. Setembro  Rio Grande do Norte
# 1      2024  09. Setembro  Rio Grande do Norte
# 2      2024  09. Setembro  Rio Grande do Norte
# 3      2024  09. Setembro  Rio Grande do Norte
# 4      2024  09. Setembro  Rio Grande do Norte
# ...     ...           ...                  ...
# 57130  1997   01. Janeiro  Rio Grande do Norte
# 57131  1997   01. Janeiro  Rio Grande do Norte
# 57132  1997   01. Janeiro  Rio Grande do Norte
# 57133  1997   01. Janeiro  Rio Grande do Norte
# 57134  1997   01. Janeiro  Rio Grande do Norte
#
#                       Bloco Econômico         Países       Via  \
# 0            América Central e Caribe        Bahamas  MARITIMA
# 1            América Central e Caribe     Costa Rica  MARITIMA
# 2            América Central e Caribe     Costa Rica  MARITIMA
# 3            América Central e Caribe    El Salvador  MARITIMA
# 4            América Central e Caribe    El Salvador  MARITIMA
# ...

# %% [markdown]
# # Acessando google planilhas e buscando dados das exportações

# %%
dataset_exportacoes_rn.describe()
# Out:
#                 Ano    Código NCM     Código SH6    Código SH4    Código SH2  \
# count  57135.000000  5.713500e+04   57135.000000  57135.000000  57135.000000
# mean    2012.328573  2.751822e+07  275182.027251   2751.457723     27.439415
# std        7.586399  2.506043e+07  250604.279740   2506.041211     25.028828
# min     1997.000000  1.019010e+06   10190.000000    101.000000      1.000000
# 25%     2006.000000  8.045020e+06   80450.000000    804.000000      8.000000
# 50%     2014.000000  1.704100e+07  170410.000000   1704.000000     17.000000
# 75%     2019.000000  5.209290e+07  520929.000000   5209.000000     52.000000
# max     2024.000000  9.998020e+07  999802.000000   9998.000000     99.000000
#
#        Valor US$ FOB  Quilograma Líquido  Quantidade Estatística
# count   5.713500e+04        5.713500e+04            5.713500e+04
# mean    1.633967e+05        5.897617e+05            2.817190e+05
# std     1.271327e+06        6.669498e+06            5.502427e+06
# ...

# %% [markdown]
# Limpar dados do Dataset
# 1. Removendo a coluna **UF do Produto** pois todos os produtos estão relacionados ao RN
# 2. Removendo as colunas **Código NCM** e **Descrição NCM** porque optamos ficar com o sistema de descrição SH para codificar e descrever os produtos.
# 3. Removendo as colunas **Código Seção** e **Descrição Seção** porque já é possível agrupar os produtos usndo o Código SH.

# %%
dataset_exportacoes_rn = dataset_exportacoes_rn.drop(columns=['UF do Produto', 'Código NCM', 'Descrição NCM', 'Código Seção', 'Descrição Seção'])

# %%
dataset_exportacoes_rn.head()
# Out:
#     Ano           Mês           Bloco Econômico       Países       Via  \
# 0  2024  09. Setembro  América Central e Caribe      Bahamas  MARITIMA
# 1  2024  09. Setembro  América Central e Caribe   Costa Rica  MARITIMA
# 2  2024  09. Setembro  América Central e Caribe   Costa Rica  MARITIMA
# 3  2024  09. Setembro  América Central e Caribe  El Salvador  MARITIMA
# 4  2024  09. Setembro  América Central e Caribe  El Salvador  MARITIMA
#
#                             URF  Código SH6  \
# 0           0420154 - IRF NATAL      271019
# 1     0817800 - PORTO DE SANTOS      520939
# 2  0917800 - PORTO DE PARANAGUA      170490
# 3           0420154 - IRF NATAL      271019
# 4      0517800 - ALF - SALVADOR      520922
#
#                                        Descrição SH6  Código SH4  \
# 0  Outros óleos de petróleo ou de minerais betumi...        2710
# 1  Outros tecidos de algodão tinto, contendo => 8...        5209
# 2          Outros produtos de confeitaria, sem cacau        1704
# ...

# %%
dataset_exportacoes_rn.describe()
# Out:
#                 Ano     Código SH6    Código SH4    Código SH2  Valor US$ FOB  \
# count  57135.000000   57135.000000  57135.000000  57135.000000   5.713500e+04
# mean    2012.328573  275182.027251   2751.457723     27.439415   1.633967e+05
# std        7.586399  250604.279740   2506.041211     25.028828   1.271327e+06
# min     1997.000000   10190.000000    101.000000      1.000000   0.000000e+00
# 25%     2006.000000   80450.000000    804.000000      8.000000   5.100000e+03
# 50%     2014.000000  170410.000000   1704.000000     17.000000   2.364500e+04
# 75%     2019.000000  520929.000000   5209.000000     52.000000   8.637450e+04
# max     2024.000000  999802.000000   9998.000000     99.000000   1.154291e+08
#
#        Quilograma Líquido  Quantidade Estatística
# count        5.713500e+04            5.713500e+04
# mean         5.897617e+05            2.817190e+05
# std          6.669498e+06            5.502427e+06
# min          0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# Conferindo os tipos de dados do dataset

# %%
#Conferindo os tipos de dados do dataset
print(dataset_exportacoes_rn.dtypes)
# Out:
# Ano                        int64
# Mês                       object
# Bloco Econômico           object
# Países                    object
# Via                       object
# URF                       object
# Código SH6                 int64
# Descrição SH6             object
# Código SH4                 int64
# Descrição SH4             object
# Código SH2                 int64
# Descrição SH2             object
# Unidade estatística       object
# Valor US$ FOB              int64
# Quilograma Líquido         int64
# Quantidade Estatística     int64
# dtype: object

# %%
#Mudando o tipo de dados das colunas Código SH6, Código SH4 e Código SH2 de inteiro para String
dataset_exportacoes_rn['Código SH6'] = dataset_exportacoes_rn['Código SH6'].astype(str)
dataset_exportacoes_rn['Código SH4'] = dataset_exportacoes_rn['Código SH4'].astype(str)
dataset_exportacoes_rn['Código SH2'] = dataset_exportacoes_rn['Código SH2'].astype(str)

# %%
print(dataset_blocos_economicos.dtypes)
# Out:
# Ano                        int64
# Mês                       object
# Bloco Econômico           object
# Países                    object
# Via                       object
# URF                       object
# Código SH6                object
# Descrição SH6             object
# Código SH4                object
# Descrição SH4             object
# Código SH2                object
# Descrição SH2             object
# Unidade estatística       object
# Valor US$ FOB              int64
# Quilograma Líquido         int64
# Quantidade Estatística     int64
# dtype: object

# %%
#Verificando se existem dados vazios
tem_dados_vazios = dataset_exportacoes_rn.isnull().any().any()
print(f"Existem dados vazios? {tem_dados_vazios}")
# Out:
# Existem dados vazios? False

# %% [markdown]
# ### Dados por continente
#
# 1.   LISTAR BLOCOS
# 2.   List item

# %% [markdown]
# Vamos fazer as mesmas alterações que foram feitas no dataset_exportacoes_rn. Todas de uma só vez.

# %%
dataset_continentes = pd.read_excel("/content/drive/MyDrive/Cópia de V_EXPORTACAO_GERAL_1997-01_2024-12_CONTINENTE_EXCEL.xlsx")
dataset_continentes
# Out:
#         Ano           Mês        UF do Produto  \
# 0      2024  09. Setembro  Rio Grande do Norte
# 1      2024  09. Setembro  Rio Grande do Norte
# 2      2024  09. Setembro  Rio Grande do Norte
# 3      2024  09. Setembro  Rio Grande do Norte
# 4      2024  09. Setembro  Rio Grande do Norte
# ...     ...           ...                  ...
# 57130  1997   01. Janeiro  Rio Grande do Norte
# 57131  1997   01. Janeiro  Rio Grande do Norte
# 57132  1997   01. Janeiro  Rio Grande do Norte
# 57133  1997   01. Janeiro  Rio Grande do Norte
# 57134  1997   01. Janeiro  Rio Grande do Norte
#
#                       Bloco Econômico         Países       Via  \
# 0            América Central e Caribe        Bahamas  MARITIMA
# 1            América Central e Caribe     Costa Rica  MARITIMA
# 2            América Central e Caribe     Costa Rica  MARITIMA
# 3            América Central e Caribe    El Salvador  MARITIMA
# 4            América Central e Caribe    El Salvador  MARITIMA
# ...

# %%
dataset_continentes.describe()
# Out:
#                 Ano    Código NCM     Código SH6    Código SH4    Código SH2  \
# count  57135.000000  5.713500e+04   57135.000000  57135.000000  57135.000000
# mean    2012.328573  2.751822e+07  275182.027251   2751.457723     27.439415
# std        7.586399  2.506043e+07  250604.279740   2506.041211     25.028828
# min     1997.000000  1.019010e+06   10190.000000    101.000000      1.000000
# 25%     2006.000000  8.045020e+06   80450.000000    804.000000      8.000000
# 50%     2014.000000  1.704100e+07  170410.000000   1704.000000     17.000000
# 75%     2019.000000  5.209290e+07  520929.000000   5209.000000     52.000000
# max     2024.000000  9.998020e+07  999802.000000   9998.000000     99.000000
#
#        Valor US$ FOB  Quilograma Líquido  Quantidade Estatística
# count   5.713500e+04        5.713500e+04            5.713500e+04
# mean    1.633967e+05        5.897617e+05            2.817190e+05
# std     1.271327e+06        6.669498e+06            5.502427e+06
# ...

# %%
#Removendo as colunas.
dataset_continentes = dataset_continentes.drop(columns=['UF do Produto', 'Código NCM', 'Descrição NCM', 'Código Seção', 'Descrição Seção'])

#Mudando o tipo de dados das colunas Código SH6, Código SH4 e Código SH2 de inteiro para String
dataset_continentes['Código SH6'] = dataset_continentes['Código SH6'].astype(str)
dataset_continentes['Código SH4'] = dataset_continentes['Código SH4'].astype(str)
dataset_continentes['Código SH2'] = dataset_continentes['Código SH2'].astype(str)

# %%
#Verificando se existem dados vazios
tem_dados_vazios = dataset_continentes.isnull().any().any()
print(f"Existem dados vazios? {tem_dados_vazios}")
# Out:
# Existem dados vazios? False

# %%
print(dataset_blocos_economicos.dtypes)
# Out:
# Ano                        int64
# Mês                       object
# Bloco Econômico           object
# Países                    object
# Via                       object
# URF                       object
# Código SH6                object
# Descrição SH6             object
# Código SH4                object
# Descrição SH4             object
# Código SH2                object
# Descrição SH2             object
# Unidade estatística       object
# Valor US$ FOB              int64
# Quilograma Líquido         int64
# Quantidade Estatística     int64
# dtype: object

# %%
dataset_blocos_economicos.describe()
# Out:
#                 Ano  Valor US$ FOB  Quilograma Líquido  Quantidade Estatística
# count  31889.000000   3.188900e+04        3.188900e+04            3.188900e+04
# mean    2012.240177   1.352886e+05        2.055934e+05            7.776450e+04
# std        7.520547   1.351684e+06        2.315952e+06            5.194471e+05
# min     1997.000000   0.000000e+00        0.000000e+00            0.000000e+00
# 25%     2006.000000   3.727000e+03        1.200000e+03            0.000000e+00
# 50%     2013.000000   1.849400e+04        1.130500e+04            1.363000e+03
# 75%     2019.000000   6.778900e+04        4.334000e+04            1.734900e+04
# max     2024.000000   1.154291e+08        2.021515e+08            3.383300e+07

# %%
dataset_blocos_economicos.head()
# Out:
#     Ano           Mês                                   Bloco Econômico  \
# 0  2024  09. Setembro  Associação de Nações do Sudeste Asiático - ASEAN
# 1  2024  09. Setembro  Associação de Nações do Sudeste Asiático - ASEAN
# 2  2024  09. Setembro                Comunidade Andina das Nações - CAN
# 3  2024  09. Setembro                Comunidade Andina das Nações - CAN
# 4  2024  09. Setembro                Comunidade Andina das Nações - CAN
#
#      Países       Via                                                URF  \
# 0   Malásia  MARITIMA                          0817800 - PORTO DE SANTOS
# 1    Vietnã     AEREA                                0420154 - IRF NATAL
# 2  Colômbia     AEREA  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...
# 3  Colômbia     AEREA  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...
# 4  Colômbia     AEREA  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...
#
#   Código SH6                                      Descrição SH6 Código SH4  \
# ...
