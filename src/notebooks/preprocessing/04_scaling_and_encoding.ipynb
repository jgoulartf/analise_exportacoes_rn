# %% [markdown]
# # Pré-processamento dos dados das exportações do RN
# ## Etapa 4 - Escalonamento, encoding e normalização dos dados
#
# <img height="200" src="https://share-eric.eu/fileadmin/_processed_/b/5/csm_dataheader_ec9ee966be.jpg" width="600"/>

# %% [markdown]
# # Carregando base de dados das exportações do RN após etapa 3 de pre-processamento

# %%
import pandas as pd

# Carrega excel em um dataframe
dataset_exportacoes_sem_outliers = pd.read_csv('../../../data/interim/preprocessing/03_dataset_expo_rn_NO_OUTLIERS_featured.csv')
dataset_exportacoes_com_outliers = pd.read_csv('../../../data/interim/preprocessing/03_dataset_expo_rn_OUTLIERS_featured.csv')
dataset_exportacoes_com_outliers.drop(["Unnamed: 0", 'ano', 'mes', 'Valor US$ FOB_mensal.1', 'Quilograma Líquido_mensal.1', 'Valor US$ FOB_anual.1', 'Quilograma Líquido_anual.1'], axis=1, inplace=True)
dataset_exportacoes_sem_outliers.drop(["Unnamed: 0", 'ano', 'mes', 'Valor US$ FOB_mensal.1', 'Quilograma Líquido_mensal.1', 'Valor US$ FOB_anual.1', 'Quilograma Líquido_anual.1'], axis=1, inplace=True)

dataset_exportacoes_com_outliers
# Out:
#        Bloco Econômico  Países  Código NCM  \
# 0                    0       8    27101911
# 1                    0      37    52093900
# 2                    0      37    17049020
# 3                    0      46    27101911
# 4                    0      46    52092200
# ...                ...     ...         ...
# 57130                6     161    17041000
# 57131                6     161    17049020
# 57132                6     161    17049090
# 57133                7      75    15211000
# 57134                7      84    25161200
#
#                                            Descrição NCM  Código SH6  \
# 0                                  Querosenes de aviação      271019
# 1      Outros tecidos de algodão que contenham pelo m...      520939
# 2      Caramelos, confeitos, dropes, pastilhas, e pro...      170490
# 3                                  Querosenes de aviação      271019
# 4      Tecidos de algodão que contenham pelo menos 85...      520922
# ...                                                  ...         ...
# 57130  Gomas de mascar, mesmo revestidas de açúcar, s...      170410
# 57131  Caramelos, confeitos, dropes, pastilhas, e pro...      170490
# 57132          Outros produtos de confeitaria, sem cacau      170490
# 57133                                     Ceras vegetais      152110
# 57134  Granito, simplesmente cortado a serra ou por o...      251612
#
#                                            Descrição SH6  Código SH4  \
# 0      Outros óleos de petróleo ou de minerais betumi...         119
# 1      Outros tecidos de algodão tinto, contendo => 8...         237
# 2              Outros produtos de confeitaria, sem cacau          66
# 3      Outros óleos de petróleo ou de minerais betumi...         119
# 4      Tecido de algodão branqueado, em ponto sarjado...         237
# ...                                                  ...         ...
# 57130  Gomas de mascar, sem cacau, mesmo revestidas d...          66
# 57131          Outros produtos de confeitaria, sem cacau          66
# 57132          Outros produtos de confeitaria, sem cacau          66
# 57133  Ceras vegetais, mesmo refinadas ou coradas (ex...          61
# 57134  Granito, cortado em blocos ou placas de forma ...         100
#
#        Descrição SH4  Código SH2  Descrição SH2  ...  Descrição Seção  \
# 0                558          25             18  ...               18
# 1                510          46              2  ...                6
# 2                452          16              6  ...               16
# 3                558          25             18  ...               18
# 4                510          46              2  ...                6
# ...              ...         ...            ...  ...              ...
# 57130            452          16              6  ...               16
# 57131            452          16              6  ...               16
# 57132            452          16              6  ...               16
# 57133            111          14             28  ...                2
# 57134            240          23             76  ...               18
#
#        Unidade estatística  Valor US$ FOB  Quilograma Líquido  \
# 0                        2          14906               11675
# 1                        8          11130                1294
# 2                        8          38824               22782
# 3                        2           1915                1482
# 4                        8          58126                9825
# ...                    ...            ...                 ...
# 57130                    8           9696                4640
# 57131                    8          40640               30275
# 57132                    8          34060               26720
# 57133                    8          45276               14000
# 57134                    2          15649               16300
#
#        Quantidade Estatística        Data Valor US$ FOB_mensal  \
# 0                          15  2024-09-01               571128
# 1                        1294  2024-09-01               190282
# 2                       22782  2024-09-01              1009459
# 3                           2  2024-09-01               571128
# 4                        9825  2024-09-01              2769669
# ...                       ...         ...                  ...
# 57130                       0  1997-01-01                93303
# 57131                       0  1997-01-01               294265
# 57132                       0  1997-01-01               294265
# 57133                      14  1997-01-01               354955
# 57134                      16  1997-01-01                15649
#
#        Quilograma Líquido_mensal  Valor US$ FOB_anual  \
# 0                         598314            453298187
# 1                          25398              1552614
# 2                         570338              7618874
# 3                         598314            453298187
# 4                         491933             11553520
# ...                          ...                  ...
# 57130                      63241              1990600
# 57131                     243061              6357902
# 57132                     243061              6357902
# 57133                      84000              1463103
# 57134                      16300                15649
#
#        Quilograma Líquido_anual
# 0                     783875921
# 1                        226207
# 2                       4239594
# 3                     783875921
# 4                       2074862
# ...                         ...
# 57130                   1261793
# 57131                   5535543
# 57132                   5535543
# 57133                    338500
# 57134                     16300
#
# [57135 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import joblib

# Criação do LabelEncoder
encoder_sem_outliers = LabelEncoder()
encoder_com_outliers = LabelEncoder()

# Lista das colunas a serem transformadas
colunas_a_transformar = ['Bloco Econômico', 'Países', 'Código NCM','Descrição NCM', 'Código SH6', 'Descrição SH6', 'Código SH4', 'Descrição SH4', 'Código SH2', 'Descrição SH2', 'Código Seção',
                         'Descrição Seção','Unidade estatística']

# Aplicar LabelEncoder nas colunas selecionadas, sobrescrevendo as colunas originais
for coluna in colunas_a_transformar:
    dataset_exportacoes_sem_outliers[coluna] = encoder_sem_outliers.fit_transform(dataset_exportacoes_sem_outliers[coluna])
    dataset_exportacoes_sem_outliers[coluna] = encoder_sem_outliers.fit_transform(dataset_exportacoes_sem_outliers[coluna])
    dataset_exportacoes_com_outliers[coluna] = encoder_com_outliers.fit_transform(dataset_exportacoes_com_outliers[coluna])
    dataset_exportacoes_com_outliers[coluna] = encoder_com_outliers.fit_transform(dataset_exportacoes_com_outliers[coluna])

# Salvar o encoder
joblib.dump(encoder_sem_outliers, '../../../models/encoder/label_encoder_sem_outliers.plk')
joblib.dump(dataset_exportacoes_com_outliers, '../../../models/encoder/label_encoder_com_outliers.plk')

# Visualizar o resultado
dataset_exportacoes_sem_outliers_encoded = dataset_exportacoes_sem_outliers
dataset_exportacoes_com_outliers_encoded = dataset_exportacoes_com_outliers
dataset_exportacoes_com_outliers_encoded
# Out:
#        Bloco Econômico  Países  Código NCM  Descrição NCM  Código SH6  \
# 0                    0       8         328           1356         265
# 1                    0      37         618           1170         510
# 2                    0      37         215            188         170
# 3                    0      46         328           1356         265
# 4                    0      46         614           1464         506
# ...                ...     ...         ...            ...         ...
# 57130                6     161         213            471         169
# 57131                6     161         215            188         170
# 57132                6     161         216           1110         170
# 57133                7      75         205            213         161
# 57134                7      84         303            477         243
#
#        Descrição SH6  Código SH4  Descrição SH4  Código SH2  Descrição SH2  \
# 0                995         119            558          25             18
# 1                961         237            510          46              2
# 2                917          66            452          16              6
# 3                995         119            558          25             18
# 4               1205         237            510          46              2
# ...              ...         ...            ...         ...            ...
# 57130            429          66            452          16              6
# 57131            917          66            452          16              6
# 57132            917          66            452          16              6
# 57133            207          61            111          14             28
# 57134            434         100            240          23             76
#
#        ...  Descrição Seção  Unidade estatística  Valor US$ FOB  \
# 0      ...               18                    2          14906
# 1      ...                6                    8          11130
# 2      ...               16                    8          38824
# 3      ...               18                    2           1915
# 4      ...                6                    8          58126
# ...    ...              ...                  ...            ...
# 57130  ...               16                    8           9696
# 57131  ...               16                    8          40640
# 57132  ...               16                    8          34060
# 57133  ...                2                    8          45276
# 57134  ...               18                    2          15649
#
#        Quilograma Líquido  Quantidade Estatística        Data  \
# 0                   11675                      15  2024-09-01
# 1                    1294                    1294  2024-09-01
# 2                   22782                   22782  2024-09-01
# 3                    1482                       2  2024-09-01
# 4                    9825                    9825  2024-09-01
# ...                   ...                     ...         ...
# 57130                4640                       0  1997-01-01
# 57131               30275                       0  1997-01-01
# 57132               26720                       0  1997-01-01
# 57133               14000                      14  1997-01-01
# 57134               16300                      16  1997-01-01
#
#       Valor US$ FOB_mensal  Quilograma Líquido_mensal  Valor US$ FOB_anual  \
# 0                   571128                     598314            453298187
# 1                   190282                      25398              1552614
# 2                  1009459                     570338              7618874
# 3                   571128                     598314            453298187
# 4                  2769669                     491933             11553520
# ...                    ...                        ...                  ...
# 57130                93303                      63241              1990600
# 57131               294265                     243061              6357902
# 57132               294265                     243061              6357902
# 57133               354955                      84000              1463103
# 57134                15649                      16300                15649
#
#        Quilograma Líquido_anual
# 0                     783875921
# 1                        226207
# 2                       4239594
# 3                     783875921
# 4                       2074862
# ...                         ...
# 57130                   1261793
# 57131                   5535543
# 57132                   5535543
# 57133                    338500
# 57134                     16300
#
# [57135 rows x 21 columns]

# %% [markdown]
# # Salvando dados apos encoding

# %%
dataset_exportacoes_com_outliers.to_csv("../../../data/interim/preprocessing/04_dataset_expo_rn_OUTLIERS_featured_encoded.csv")
dataset_exportacoes_sem_outliers.to_csv("../../../data/interim/preprocessing/04_dataset_expo_rn_NO_OUTLIERS_featured_encoded.csv")
